# %%
import pandas as pd
df = pd.read_csv("Cars24 data.csv")
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8118             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8119         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8120        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8121               Tata Indigo CR4  2013         290000      25000  Diesel
# 8122               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.tail()
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 8118       Hyundai i20 Magna  2013         320000     110000  Petrol
# 8119   Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8120  Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8121         Tata Indigo CR4  2013         290000      25000  Diesel
# 8122         Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission        owner     mileage   engine  max_power  \
# 8118  Individual       Manual  First Owner   18.5 kmpl  1197 CC  82.85 bhp
# 8119  Individual       Manual  Third Owner   16.8 kmpl  1493 CC    110 bhp
# 8120  Individual       Manual  First Owner   19.3 kmpl  1248 CC   73.9 bhp
# 8121  Individual       Manual  First Owner  23.57 kmpl  1396 CC     70 bhp
# 8122  Individual       Manual  First Owner  23.57 kmpl  1396 CC     70 bhp
#
#                          torque  seats
# 8118           113.7Nm@ 4000rpm    5.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8123 entries, 0 to 8122
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8123 non-null   object
#  1   year           8123 non-null   int64
#  2   selling_price  8123 non-null   int64
#  3   km_driven      8123 non-null   int64
#  4   fuel           8123 non-null   object
#  5   seller_type    8123 non-null   object
#  6   transmission   8123 non-null   object
#  7   owner          8123 non-null   object
#  8   mileage        7902 non-null   object
#  9   engine         7902 non-null   object
#  10  max_power      7908 non-null   object
#  11  torque         7901 non-null   object
#  12  seats          7902 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.1+ KB

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
True + True + False + True
# Out:
# 3

# %%
df.shape
# Out:
# (8123, 13)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (7901, 13)

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.fuel.unique()
# Out:
# array(['Diesel', 'Petrol', 'CNG', 'LPG'], dtype=object)

# %%
fuel_dic = {
    'Diesel': 0, 
    'Petrol': 1, 
    'CNG': 2, 
    'LPG': 3
}
df.fuel = df.fuel.map(fuel_dic)

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven  fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500     0
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     0
# 2      Honda City 2017-2020 EXi  2006         158000     140000     1
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000     0
# 4        Maruti Swift VXI BSIII  2007         130000     120000     1
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.seller_type.unique()
# Out:
# array(['Individual', 'Dealer'], dtype=object)

# %%
seller_dic = {
    'Individual':0,
    'Dealer':1
}
df.seller_type = df.seller_type.map(seller_dic)

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven  fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500     0
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     0
# 2      Honda City 2017-2020 EXi  2006         158000     140000     1
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000     0
# 4        Maruti Swift VXI BSIII  2007         130000     120000     1
#
#    seller_type transmission         owner     mileage   engine   max_power  \
# 0            0       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1            0       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2            0       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3            0       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4            0       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.transmission.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
trans_dic = {
    'Manual':0, 
    'Automatic':1
}
df.transmission = df.transmission.map(trans_dic)

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven  fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500     0
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     0
# 2      Honda City 2017-2020 EXi  2006         158000     140000     1
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000     0
# 4        Maruti Swift VXI BSIII  2007         130000     120000     1
#
#    seller_type  transmission         owner     mileage   engine   max_power  \
# 0            0             0   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1            0             0  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2            0             0   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3            0             0   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4            0             0   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.owner.unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner'], dtype=object)

# %%
df.mileage = df.mileage.str.replace(" kmpl", "").astype(float)

# %%
df
# Out:
#                               name  year  selling_price  km_driven  fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500     0
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000     0
# 2         Honda City 2017-2020 EXi  2006         158000     140000     1
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000     0
# 4           Maruti Swift VXI BSIII  2007         130000     120000     1
# ...                            ...   ...            ...        ...   ...
# 8118             Hyundai i20 Magna  2013         320000     110000     1
# 8119         Hyundai Verna CRDi SX  2007         135000     119000     0
# 8120        Maruti Swift Dzire ZDi  2009         382000     120000     0
# 8121               Tata Indigo CR4  2013         290000      25000     0
# 8122               Tata Indigo CR4  2013         290000      25000     0
#
#       seller_type  transmission         owner  mileage   engine   max_power  \
# ...
